# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in e:\program files\python\lib\site-packages (1.50.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in e:\program files\python\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in e:\program files\python\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in e:\program files\python\lib\site-packages (from streamlit) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in e:\program files\python\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in e:\program files\python\lib\site-packages (from streamlit) (2.3.1)
# Requirement already satisfied: packaging<26,>=20 in e:\program files\python\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in e:\program files\python\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in e:\program files\python\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in e:\program files\python\lib\site-packages (from streamlit) (6.32.1)
# Requirement already satisfied: pyarrow>=7.0 in e:\program files\python\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in e:\program files\python\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in e:\program files\python\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in e:\program files\python\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in e:\program files\python\lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in e:\program files\python\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in e:\program files\python\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in e:\program files\python\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in e:\program files\python\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in e:\program files\python\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in e:\program files\python\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in e:\program files\python\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.0.0)
# Requirement already satisfied: colorama in e:\program files\python\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in e:\program files\python\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in e:\program files\python\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\program files\python\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\program files\python\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\program files\python\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\program files\python\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\program files\python\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\program files\python\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\program files\python\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\program files\python\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in e:\program files\python\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\program files\python\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\program files\python\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\program files\python\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in e:\program files\python\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# WARNING: Ignoring invalid distribution ~upyterlab (E:\Program Files\python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (E:\Program Files\python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (E:\Program Files\python\Lib\site-packages)

# %%
import streamlit as st
import pandas as pd
import numpy as np
import joblib

# -------------------------------
# Load Models and Data
# -------------------------------
@st.cache_data
def load_models_and_data():
    model1 = joblib.load("best_model_model1.pkl")
    model2 = joblib.load("model2_best_regressor.pkl")
    feature_names_model2 = joblib.load("model2_feature_names.pkl")

    df_processed = pd.read_csv("df_final_features_v2.csv")     # for model 1
    df_raw = pd.read_csv("original_dataset.csv")               # original data
    df_model2 = pd.read_csv("D:/LOAN APP PROJECT/data/df_model2_features.csv")  # for model 2

    return model1, model2, feature_names_model2, df_processed, df_raw, df_model2

# Load everything
model1, model2, feature_names_model2, df_processed, df_raw, df_model2 = load_models_and_data()

# Merge loan_id into processed df
if 'loan_id' not in df_processed.columns and 'loan_id' in df_raw.columns:
    df_processed = pd.concat([df_raw[['loan_id']].reset_index(drop=True),
                              df_processed.reset_index(drop=True)], axis=1)

# Merge model2 df with loan_id (only approved ones)
df_model2 = pd.merge(df_model2, df_raw[['loan_id']], left_index=True, right_index=True, how='left')

# -------------------------------
# Streamlit UI
# -------------------------------
st.title("🏦 Loan Prediction Web App")
st.markdown("Enter a **Loan ID** below to predict approval status and loan amount (if applicable).")

loan_id_input = st.text_input("🔢 Enter Loan ID", "")

if loan_id_input:
    if not loan_id_input.isdigit():
        st.error("Please enter a valid numeric Loan ID.")
    else:
        loan_id_input = int(loan_id_input)
        row = df_processed[df_processed["loan_id"] == loan_id_input]

        if row.empty:
            st.error(f"Loan ID {loan_id_input} not found.")
        else:
            X_model1 = row[model1.feature_names_in_].apply(pd.to_numeric, errors='coerce').fillna(0)
            y_pred = model1.predict(X_model1)[0]
            try:
                prob = model1.predict_proba(X_model1)[0][0]
            except:
                prob = None

            label_map = {0: "✅ Approved", 1: "❌ Rejected"}
            status = label_map.get(y_pred, "Unknown")

            st.subheader("🔍 Prediction Result")
            st.write(f"**Loan ID:** {loan_id_input}")
            st.write(f"**Status:** {status}")
            if prob is not None:
                st.write(f"**Approval Probability:** {prob:.2%}")

            # Show original data
            st.subheader("📋 Original Loan Application Data")
            st.dataframe(df_raw[df_raw["loan_id"] == loan_id_input])

            # Predict loan amount if approved
            if y_pred == 0:
                row2 = df_model2[df_model2["loan_id"] == loan_id_input]
                if row2.empty:
                    st.warning("Loan ID not found in Model 2 dataset.")
                else:
                    X_model2 = row2[feature_names_model2].apply(pd.to_numeric, errors='coerce').fillna(0)
                    loan_log = model2.predict(X_model2)[0]
                    loan_amount = np.expm1(loan_log)
                    st.subheader("💰 Predicted Loan Amount")
                    st.success(f"₹{loan_amount:,.2f}")
# Out:
# 2025-10-14 16:01:23.928 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-14 16:01:23.932 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-14 16:01:23.934 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:25.771
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run E:\Program Files\python\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-10-14 16:01:25.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:25.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:25.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:26.290 Thread 'Thread-7': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:26.297 Thread 'Thread-7': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:26.299 Thread 'Thread-7': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# E:\Program Files\python\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.7.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# E:\Program Files\python\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.7.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# E:\Program Files\python\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.7.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# E:\Program Files\python\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator RandomForestRegressor from version 1.7.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2025-10-14 16:01:37.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.838 Session state does not function when running a script without `streamlit run`
# 2025-10-14 16:01:37.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 16:01:37.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
